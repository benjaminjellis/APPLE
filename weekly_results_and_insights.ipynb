# %%
from analytics.results import Results, Predictions
from analytics.visulisation import Visualisation

# %% [markdown]
# ## This Week's Predictions

# %%
Predictions(user_predictions = "data/user_predictions/20_21/week7/week7userpredictions.csv",
        apple_predictions =
        "results/20_21/week7/7640a728-04fb-11eb-8c32-acde48001122_predicted_results.csv").show()
# Out:
#            HomeTeam        AwayTeam       Date  FixtureID APPLE Prediction  \
# 0            Wolves  Crystal Palace 2020-10-30         58                A
# 1  Sheffield United        Man City 2020-10-31         59                A
# 2           Burnley         Chelsea 2020-10-31         60                A
# 3         Liverpool        West Ham 2020-10-31         61                H
# 4       Aston Villa     Southampton 2020-11-01         62                H
# 5         Newcastle         Everton 2020-11-01         63                A
# 6        Man United         Arsenal 2020-11-01         64                H
# 7         Tottenham        Brighton 2020-11-01         65                H
# 8            Fulham       West Brom 2020-11-02         66                H
# 9             Leeds       Leicester 2020-11-02         67                H
#
#   Admin Prediction Dev Prediction Jordan Prediction Leanne Prediction  \
# 0                D              H                 H                 D
# 1                A              D                 A                 A
# 2                A              A                 A                 A
# 3                A              H                 H                 H
# 4                H              H                 D                 A
# 5                H              A                 A                 A
# 6                A              D                 H                 H
# 7                H              H                 H                 H
# 8                H              A                 A                 D
# 9                A              H                 H                 A
#
#   Marvyn Prediction
# 0                 A
# 1                 A
# 2                 A
# 3                 H
# 4                 D
# 5                 A
# 6                 H
# 7                 H
# 8                 D
# 9                 A

# %% [markdown]
# ## Last Week's Results

# %%
Results(user_predictions = "data/user_predictions/20_21/week7/week7userpredictions.csv",
        apple_predictions =
        "results/20_21/week7/7640a728-04fb-11eb-8c32-acde48001122_predicted_results.csv").aggregate(
        ftrs = "data/ftrs/20_21/week7/ftrs.csv",
        winners_log = "data/aggregated_results/20_21/winners_log.csv", 
        aggregated_results_file = "data/aggregated_results/20_21/predictions_and_results_log.csv")
# Out:
#        Time  Week          HomeTeam        AwayTeam  FixtureID  \
# 0  20:00:00     7            Wolves  Crystal Palace         58
# 1  12:30:00     7  Sheffield United        Man City         59
# 2  15:00:00     7           Burnley         Chelsea         60
# 3  17:30:00     7         Liverpool        West Ham         61
# 4  12:00:00     7       Aston Villa     Southampton         62
# 5  14:00:00     7         Newcastle         Everton         63
# 6  16:30:00     7        Man United         Arsenal         64
# 7  19:15:00     7         Tottenham        Brighton         65
# 8  17:30:00     7            Fulham       West Brom         66
# 9  20:00:00     7             Leeds       Leicester         67
#
#   APPLE Prediction Admin Prediction Dev Prediction Jordan Prediction  \
# 0                A                D              H                 H
# 1                A                A              D                 A
# 2                A                A              A                 A
# 3                H                A              H                 H
# 4                H                H              H                 D
# 5                A                H              A                 A
# 6                H                A              D                 H
# 7                H                H              H                 H
# 8                H                H              A                 A
# 9                H                A              H                 H
#
#   Leanne Prediction Marvyn Prediction FTR
# 0                 D                 A   H
# 1                 A                 A   A
# 2                 A                 A   A
# 3                 H                 H   H
# 4                 A                 D   A
# 5                 A                 A   H
# 6                 H                 H   A
# 7                 H                 H   H
# 8                 D                 D   H
# 9                 A                 A   A
# Last week's results:
#   Predictor Correct Predictions Week Accuracy of Predictions (%)
# 0     Admin                   7    7                          70
# 1    Leanne                   6    7                          60
# 2     APPLE                   5    7                          50
# 3    Jordan                   5    7                          50
# 4    Marvyn                   5    7                          50
# 5       Dev                   4    7                          40
# This weeks' winner(s): Admin
#
# results to date:
#   Predictor Correct Predictions Accuracy of Predictions (%)
# 0    Leanne                  34                     50.7463
# 1    Marvyn                  33                     49.2537
# 2     APPLE                  32                     47.7612
# 3    Jordan                  30                     44.7761
# 4       Dev                  26                      38.806
# 5     Admin                  11                     16.4179
# 6       Ben                   0                           0
# Overall winner(s): Leanne
