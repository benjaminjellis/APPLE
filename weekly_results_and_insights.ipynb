# %%
from analytics.results import Results, Predictions
from analytics.visulisation import Visualisation

# %% [markdown]
# ## This Week's Predictions

# %%
Predictions(user_predictions = "data/user_predictions/20_21/week7/week7userpredictions.csv",
        apple_predictions =
        "results/20_21/week7/7640a728-04fb-11eb-8c32-acde48001122_predicted_results.csv").show()
# Out:
#            HomeTeam        AwayTeam       Date APPLE Prediction  \
# 0            Wolves  Crystal Palace 2020-10-30                A
# 1  Sheffield United        Man City 2020-10-31                A
# 2           Burnley         Chelsea 2020-10-31                A
# 3         Liverpool        West Ham 2020-10-31                H
# 4       Aston Villa     Southampton 2020-11-01                H
# 5         Newcastle         Everton 2020-11-01                A
# 6        Man United         Arsenal 2020-11-01                H
# 7         Tottenham        Brighton 2020-11-01                H
# 8            Fulham       West Brom 2020-11-02                H
# 9             Leeds       Leicester 2020-11-02                H
#
#    fixtureId Prediction Admin Prediction Dev Prediction Jordan Prediction  \
# 0                    58                D              H                 H
# 1                    59                A              D                 A
# 2                    60                A              A                 A
# 3                    61                A              H                 H
# 4                    62                H              H                 D
# 5                    63                H              A                 A
# 6                    64                A              D                 H
# 7                    65                H              H                 H
# 8                    66                H              A                 A
# 9                    67                A              H                 H
#
#   Leanne Prediction Marvyn Prediction
# 0                 D                 A
# 1                 A                 A
# 2                 A                 A
# 3                 H                 H
# 4                 A                 D
# 5                 A                 A
# 6                 H                 H
# 7                 H                 H
# 8                 D                 D
# 9                 A                 A

# %% [markdown]
# ## Last Week's Results

# %%
"""
Results(user_predictions = "data/user_predictions/20_21/week6/week6userpredictions.csv",
        apple_predictions =
        "results/20_21/week6/7640a728-04fb-11eb-8c32-acde48001122_predicted_results.csv").aggregate(
        ftrs = "data/ftrs/20_21/week6/ftrs.csv",
        winners_log = "data/aggregated_results/20_21/winners_log.csv", 
        aggregated_results_file = "data/aggregated_results/20_21/predictions_and_results_log.csv")
"""
# Out:
# '\nResults(user_predictions = "data/user_predictions/20_21/week6/week6userpredictions.csv",\n        apple_predictions =\n        "results/20_21/week6/7640a728-04fb-11eb-8c32-acde48001122_predicted_results.csv").aggregate(\n        ftrs = "data/ftrs/20_21/week6/ftrs.csv",\n        winners_log = "data/aggregated_results/20_21/winners_log.csv", \n        aggregated_results_file = "data/aggregated_results/20_21/predictions_and_results_log.csv")\n'
